# %% [markdown]
# <a href="https://colab.research.google.com/github/Datriks/Pandas_Data_analysis/blob/master/Label_based_indexing_and_Slicing_with_loc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
summer = pd.read_csv('summer.csv',index_col = 'Athlete')
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31165 entries, HAJOS, Alfred to LIDBERG, Jimmy
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Country     31161 non-null  object
#  5   Gender      31165 non-null  object
#  6   Event       31165 non-null  object
#  7   Medal       31165 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %%
summer.head()
# Out:
#                     Year    City  ...                       Event   Medal
# Athlete                           ...
# HAJOS, Alfred       1896  Athens  ...              100M Freestyle    Gold
# HERSCHMANN, Otto    1896  Athens  ...              100M Freestyle  Silver
# DRIVAS, Dimitrios   1896  Athens  ...  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  1896  Athens  ...  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  1896  Athens  ...  100M Freestyle For Sailors  Silver
#
# [5 rows x 8 columns]

# %%
summer.iloc[2]
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: DRIVAS, Dimitrios, dtype: object

# %%
summer.loc['DRIVAS, Dimitrios']
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: DRIVAS, Dimitrios, dtype: object

# %%
summer.loc['PHELPS, Michael']
# Out:
#                  Year     City     Sport  ... Gender                   Event   Medal
# Athlete                                   ...
# PHELPS, Michael  2004   Athens  Aquatics  ...    Men          100M Butterfly    Gold
# PHELPS, Michael  2004   Athens  Aquatics  ...    Men          200M Butterfly    Gold
# PHELPS, Michael  2004   Athens  Aquatics  ...    Men          200M Freestyle  Bronze
# PHELPS, Michael  2004   Athens  Aquatics  ...    Men  200M Individual Medley    Gold
# PHELPS, Michael  2004   Athens  Aquatics  ...    Men  400M Individual Medley    Gold
# PHELPS, Michael  2004   Athens  Aquatics  ...    Men  4X100M Freestyle Relay  Bronze
# PHELPS, Michael  2004   Athens  Aquatics  ...    Men     4X100M Medley Relay    Gold
# PHELPS, Michael  2004   Athens  Aquatics  ...    Men  4X200M Freestyle Relay    Gold
# PHELPS, Michael  2008  Beijing  Aquatics  ...    Men          100M Butterfly    Gold
# PHELPS, Michael  2008  Beijing  Aquatics  ...    Men          200M Butterfly    Gold
# PHELPS, Michael  2008  Beijing  Aquatics  ...    Men          200M Freestyle    Gold
# PHELPS, Michael  2008  Beijing  Aquatics  ...    Men  200M Individual Medley    Gold
# PHELPS, Michael  2008  Beijing  Aquatics  ...    Men  400M Individual Medley    Gold
# PHELPS, Michael  2008  Beijing  Aquatics  ...    Men  4X100M Freestyle Relay    Gold
# PHELPS, Michael  2008  Beijing  Aquatics  ...    Men     4X100M Medley Relay    Gold
# PHELPS, Michael  2008  Beijing  Aquatics  ...    Men  4X200M Freestyle Relay    Gold
# PHELPS, Michael  2012   London  Aquatics  ...    Men          100M Butterfly    Gold
# PHELPS, Michael  2012   London  Aquatics  ...    Men          200M Butterfly  Silver
# PHELPS, Michael  2012   London  Aquatics  ...    Men             200M Medley    Gold
# PHELPS, Michael  2012   London  Aquatics  ...    Men        4X100M Freestyle  Silver
# PHELPS, Michael  2012   London  Aquatics  ...    Men           4X100M Medley    Gold
# PHELPS, Michael  2012   London  Aquatics  ...    Men        4X200M Freestyle    Gold
#
# [22 rows x 8 columns]

# %% [markdown]
# ### Indexing and Slicing Rows and Columns with loc[]

# %%
summer.loc['PHELPS, Michael', 'Medal']
# Out:
# Athlete
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Bronze
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Bronze
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Silver
# PHELPS, Michael      Gold
# PHELPS, Michael    Silver
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# Name: Medal, dtype: object

# %%
summer.loc['PHELPS, Michael', ['Medal','Event']]
# Out:
#                   Medal                   Event
# Athlete
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael  Bronze          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael  Bronze  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael    Gold          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael    Gold  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael  Silver          200M Butterfly
# PHELPS, Michael    Gold             200M Medley
# PHELPS, Michael  Silver        4X100M Freestyle
# PHELPS, Michael    Gold           4X100M Medley
# PHELPS, Michael    Gold        4X200M Freestyle

# %%
summer.loc[['PHELPS, Michael','LEWIS, Carl'], ['Medal','Event']]
# Out:
#                   Medal                   Event
# Athlete
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael  Bronze          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael  Bronze  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael    Gold          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael    Gold  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael  Silver          200M Butterfly
# PHELPS, Michael    Gold             200M Medley
# PHELPS, Michael  Silver        4X100M Freestyle
# PHELPS, Michael    Gold           4X100M Medley
# PHELPS, Michael    Gold        4X200M Freestyle
# LEWIS, Carl        Gold                    100M
# LEWIS, Carl        Gold                    200M
# LEWIS, Carl        Gold            4X100M Relay
# LEWIS, Carl        Gold               Long Jump
# LEWIS, Carl        Gold                    100M
# LEWIS, Carl      Silver                    200M
# LEWIS, Carl        Gold               Long Jump
# LEWIS, Carl        Gold            4X100M Relay
# LEWIS, Carl        Gold               Long Jump
# LEWIS, Carl        Gold               Long Jump

# %%
summer.loc[:,['Medal','Event']]
# Out:
#                             Medal                       Event
# Athlete
# HAJOS, Alfred                Gold              100M Freestyle
# HERSCHMANN, Otto           Silver              100M Freestyle
# DRIVAS, Dimitrios          Bronze  100M Freestyle For Sailors
# MALOKINIS, Ioannis           Gold  100M Freestyle For Sailors
# CHASAPIS, Spiridon         Silver  100M Freestyle For Sailors
# ...                           ...                         ...
# JANIKOWSKI, Damian         Bronze                    Wg 84 KG
# REZAEI, Ghasem Gholamreza    Gold                    Wg 96 KG
# TOTROV, Rustam             Silver                    Wg 96 KG
# ALEKSANYAN, Artur          Bronze                    Wg 96 KG
# LIDBERG, Jimmy             Bronze                    Wg 96 KG
#
# [31165 rows x 2 columns]

# %%
summer.head(10)
# Out:
#                        Year    City  ...                       Event   Medal
# Athlete                              ...
# HAJOS, Alfred          1896  Athens  ...              100M Freestyle    Gold
# HERSCHMANN, Otto       1896  Athens  ...              100M Freestyle  Silver
# DRIVAS, Dimitrios      1896  Athens  ...  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis     1896  Athens  ...  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon     1896  Athens  ...  100M Freestyle For Sailors  Silver
# CHOROPHAS, Efstathios  1896  Athens  ...             1200M Freestyle  Bronze
# HAJOS, Alfred          1896  Athens  ...             1200M Freestyle    Gold
# ANDREOU, Joannis       1896  Athens  ...             1200M Freestyle  Silver
# CHOROPHAS, Efstathios  1896  Athens  ...              400M Freestyle  Bronze
# NEUMANN, Paul          1896  Athens  ...              400M Freestyle    Gold
#
# [10 rows x 8 columns]

# %%
summer.loc[:'CHASAPIS, Spiridon']
# Out:
#                     Year    City  ...                       Event   Medal
# Athlete                           ...
# HAJOS, Alfred       1896  Athens  ...              100M Freestyle    Gold
# HERSCHMANN, Otto    1896  Athens  ...              100M Freestyle  Silver
# DRIVAS, Dimitrios   1896  Athens  ...  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  1896  Athens  ...  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  1896  Athens  ...  100M Freestyle For Sailors  Silver
#
# [5 rows x 8 columns]

# %%
# multiple ocurences of phelps, pandas does not know from where to slice
summer.loc[:,'PHELPS, Michael']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PHELPS, Michael'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-2f73e380b013> in <module>()
# ----> 1 summer.loc[:,'PHELPS, Michael']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1270     def _getitem_tuple(self, tup: Tuple):
#    1271         try:
# -> 1272             return self._getitem_lowerdim(tup)
#    1273         except IndexingError:
#    1274             pass
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1387         for i, key in enumerate(tup):
#    1388             if is_label_like(key) or isinstance(key, tuple):
# -> 1389                 section = self._getitem_axis(key, axis=i)
#    1390
#    1391                 # we have yielded a scalar ?
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1963         # fall thru to straight lookup
#    1964         self._validate_key(key, axis)
# -> 1965         return self._get_label(key, axis=axis)
#    1966
#    1967
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     623             raise IndexingError("no slices here, handle elsewhere")
#     624
# --> 625         return self.obj._xs(label, axis=axis)
#     626
#     627     def _get_loc(self, key: int, axis: int):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3527
#    3528         if axis == 1:
# -> 3529             return self[key]
#    3530
#    3531         self._consolidate_inplace()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PHELPS, Michael'

# %%
summer.head(10)
# Out:
#                        Year    City  ...                       Event   Medal
# Athlete                              ...
# HAJOS, Alfred          1896  Athens  ...              100M Freestyle    Gold
# HERSCHMANN, Otto       1896  Athens  ...              100M Freestyle  Silver
# DRIVAS, Dimitrios      1896  Athens  ...  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis     1896  Athens  ...  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon     1896  Athens  ...  100M Freestyle For Sailors  Silver
# CHOROPHAS, Efstathios  1896  Athens  ...             1200M Freestyle  Bronze
# HAJOS, Alfred          1896  Athens  ...             1200M Freestyle    Gold
# ANDREOU, Joannis       1896  Athens  ...             1200M Freestyle  Silver
# CHOROPHAS, Efstathios  1896  Athens  ...              400M Freestyle  Bronze
# NEUMANN, Paul          1896  Athens  ...              400M Freestyle    Gold
#
# [10 rows x 8 columns]

# %%
summer.loc['DRIVAS, Dimitrios':'BLAKE, Arthur']
# Out:
#                        Year    City  ...                       Event   Medal
# Athlete                              ...
# DRIVAS, Dimitrios      1896  Athens  ...  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis     1896  Athens  ...  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon     1896  Athens  ...  100M Freestyle For Sailors  Silver
# CHOROPHAS, Efstathios  1896  Athens  ...             1200M Freestyle  Bronze
# HAJOS, Alfred          1896  Athens  ...             1200M Freestyle    Gold
# ANDREOU, Joannis       1896  Athens  ...             1200M Freestyle  Silver
# CHOROPHAS, Efstathios  1896  Athens  ...              400M Freestyle  Bronze
# NEUMANN, Paul          1896  Athens  ...              400M Freestyle    Gold
# PEPANOS, Antonios      1896  Athens  ...              400M Freestyle  Silver
# LANE, Francis          1896  Athens  ...                        100M  Bronze
# SZOKOLYI, Alajos       1896  Athens  ...                        100M  Bronze
# BURKE, Thomas          1896  Athens  ...                        100M    Gold
# HOFMANN, Fritz         1896  Athens  ...                        100M  Silver
# CURTIS, Thomas         1896  Athens  ...                110M Hurdles    Gold
# GOULDING, Grantley     1896  Athens  ...                110M Hurdles  Silver
# LERMUSIAUX, Albin      1896  Athens  ...                       1500M  Bronze
# FLACK, Edwin           1896  Athens  ...                       1500M    Gold
# BLAKE, Arthur          1896  Athens  ...                       1500M  Silver
#
# [18 rows x 8 columns]

# %%
summer.loc['DRIVAS, Dimitrios':'BLAKE, Arthur','City':'Discipline']
# Out:
#                          City      Sport Discipline
# Athlete
# DRIVAS, Dimitrios      Athens   Aquatics   Swimming
# MALOKINIS, Ioannis     Athens   Aquatics   Swimming
# CHASAPIS, Spiridon     Athens   Aquatics   Swimming
# CHOROPHAS, Efstathios  Athens   Aquatics   Swimming
# HAJOS, Alfred          Athens   Aquatics   Swimming
# ANDREOU, Joannis       Athens   Aquatics   Swimming
# CHOROPHAS, Efstathios  Athens   Aquatics   Swimming
# NEUMANN, Paul          Athens   Aquatics   Swimming
# PEPANOS, Antonios      Athens   Aquatics   Swimming
# LANE, Francis          Athens  Athletics  Athletics
# SZOKOLYI, Alajos       Athens  Athletics  Athletics
# BURKE, Thomas          Athens  Athletics  Athletics
# HOFMANN, Fritz         Athens  Athletics  Athletics
# CURTIS, Thomas         Athens  Athletics  Athletics
# GOULDING, Grantley     Athens  Athletics  Athletics
# LERMUSIAUX, Albin      Athens  Athletics  Athletics
# FLACK, Edwin           Athens  Athletics  Athletics
# BLAKE, Arthur          Athens  Athletics  Athletics

# %%
summer.loc['PHELPS, Michael']
